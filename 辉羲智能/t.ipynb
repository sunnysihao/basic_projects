# %%
import math


line = {
                "type": "beziercurve",
                "id": "c0dc957d-66f0-4b15-a481-4304802173d5",
                "color": "#000080",
                "label": [
                    "curb"
                ],
                "code": [
                    "路沿"
                ],
                "category": [
                    "大类别"
                ],
                "catetips": [
                    "大类别"
                ],
                "label_id": [
                    "QKHIA"
                ],
                "text": "",
                "labelAttrs": [],
                "width": 0,
                "height": 0,
                "area": 0,
                "strokeWidth": 1,
                "coordinate": [
                    {
                        "x": 0,
                        "y": 1428.319581,
                        "handle": {
                            "x": 25.260545,
                            "y": 1430.392227
                        },
                        "handle2": {
                            "x": 0,
                            "y": 1428.319581
                        }
                    },
                    {
                        "x": 191.826639,
                        "y": 1444.0590950000001,
                        "handle": {
                            "x": 199.28372999999999,
                            "y": 1444.0590950000001
                        },
                        "handle2": {
                            "x": 166.56609399999999,
                            "y": 1441.986449
                        }
                    },
                    {
                        "x": 201.842536,
                        "y": 1444.0590950000001,
                        "handle": {
                            "x": 227.18249399999999,
                            "y": 1436.8346409999999
                        },
                        "handle2": {
                            "x": 194.38544400000001,
                            "y": 1444.0590950000001
                        }
                    },
                    {
                        "x": 462.329632,
                        "y": 1369.7938939999999,
                        "handle": {
                            "x": 487.36672600000003,
                            "y": 1363.614429
                        },
                        "handle2": {
                            "x": 436.98967499999998,
                            "y": 1377.0183480000001
                        }
                    },
                    {
                        "x": 677.224964,
                        "y": 1316.7550659999999,
                        "handle": {
                            "x": 701.78569900000002,
                            "y": 1310.7797069999999
                        },
                        "handle2": {
                            "x": 652.18786999999998,
                            "y": 1322.9345310000001
                        }
                    },
                    {
                        "x": 860.48207300000001,
                        "y": 1272.170607,
                        "handle": {
                            "x": 879.81186400000001,
                            "y": 1267.6602519999999
                        },
                        "handle2": {
                            "x": 835.92133799999999,
                            "y": 1278.145966
                        }
                    },
                    {
                        "x": 920.89015900000004,
                        "y": 1258.0751660000001,
                        "handle": {
                            "x": 940.13812700000005,
                            "y": 1253.8850660000001
                        },
                        "handle2": {
                            "x": 901.56036800000004,
                            "y": 1262.585521
                        }
                    },
                    {
                        "x": 980.09008300000005,
                        "y": 1245.1879060000001,
                        "handle": {
                            "x": 1001.175797,
                            "y": 1241.141089
                        },
                        "handle2": {
                            "x": 960.84211500000004,
                            "y": 1249.378005
                        }
                    },
                    {
                        "x": 1059.828757,
                        "y": 1229.884284,
                        "handle": {
                            "x": 1059.828757,
                            "y": 1229.884284
                        },
                        "handle2": {
                            "x": 1038.7430429999999,
                            "y": 1233.9311009999999
                        }
                    }
                ],
                "editable": True,
                "cBy": "184783",
                "cTime": 1660983222821,
                "cStep": "91978",
                "mBy": "184783",
                "mTime": 1662687144847,
                "mStep": "91978",
                "eBy": "",
                "eStep": "",
                "eTime": "",
                "vBy": "184783,184783,220271",
                "vStep": "91978,91979,91980",
                "vTime": "1662692302,1662692313,1662706239",
                "orientation": "0",
                "pointAttr": [],
                "_valid": True,
                "invisible": False,
                "intId": 30,
                "_index": 0,
                "_fromAi": False,
                "ih": 2160,
                "iw": 3840,
                "minWidth": 0,
                "maxWidth": None,
                "minHeight": 0,
                "maxHeight": None,
                "minArea": 0,
                "maxArea": None,
                "frame": 4,
                "standardWidth": 0,
                "standardHight": 0,
                "standardDepth": 0,
                "is_submitted": True
            }

# %%
frame_number = line['frame']
int_id = line['intId']
line_type = line['type']
ih = line['ih']
iw = line['iw']
if frame_number == frame_match:
    if line_type == 'beziercurve':
        pointattr = line['pointAttr']
        points = []
        points_t = []
        dash_pairs = []
        occ_pairs = []
        dash_l = []
        occ_l = []
        dash_pid_l = []
        occ_pid_l = []
        if pointattr:
            for pid in pointattr.keys():
                if pointattr[pid]['label'][0] in ['dash_start', 'dash_end']:
                    dash_pid_l.append(pid)
                else:
                    occ_pid_l.append(p
        x_list = []
        y_list = []
        for point in line['coordinate']:
            x = point['x']
            x_list.append(x)
            y = point['y']
            y_list.append(y)
            points.append([x, y])
            points_t.append((x, y))
            if "pid" in point.keys():
                pid_id = point['pid']
                do_x = point['x']
                do_y = point['y']
                if pid_id in dash_pid_l:
                    location = (do_x, do_y)
                    dash_l.append(location)
                else:
                    location = (do_x, do_y)
                    occ_l.append(location)
        s_point = sorted(points_t, key=lambda obj: obj[0])
        x_min = min(x_list)
        x_max = max(x_list)
        for i in range(len(points)-1):
            x1 = s_point[i][0]
            y1 = s_point[i][1]
            x2 = s_point[i+1][0]
            y2 = s_point[i+1][1]
            t_xy = math.sqrt(float((y2-y1)**2 + (x2-x1)**2))
            while t_xy > 20 and x1 != x2:
                k = (y1 - y2) / (x1 - x2)
                b = y2 - k * x2
                nx = x1+20*math.cos(math.atan(k))
                ny = k*nx + b
                points.append([nx, ny])
                x1 = nx
                y1 = ny
                t_xy = math.sqrt(float((y2 - y1) ** 2 + (x2 - x1) ** 2))
            else:
                break
