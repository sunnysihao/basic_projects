# %%
import os
import scipy.io as io
data=io.loadmat('1657162536735.mat')
print(data)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Tue Jul 12 14:46:53 2022', '__version__': '1.0', '__globals__': [], 'lidar_points': array([[2.8853467e+00, 4.9145428e+01, 1.2676771e+01, 1.1764706e-01],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#        [1.3225386e+00, 6.4207779e+01, 1.4921157e+01, 7.8431377e-03],
#        ...,
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#       dtype=float32), 'pos': array([[116.32094811,  39.98813634,  51.6027    ]]), 'ori': array([[0.00670965, 0.00718223, 0.0411381 ]]), 'pos_ori_cov': array([[3.43310000e+000, 3.20660000e+000, 9.35790000e+000,
#         4.63817943e-310, 3.16202013e-322, 1.72922976e-322]]), 'vel': array([[0.0132, 0.0176, 0.024 ]]), 'omg': array([[0., 0., 0.]]), 'camera_front': array([[[ 89, 133, 110],
# ...

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'lidar_points', 'pos', 'ori', 'pos_ori_cov', 'vel', 'omg', 'camera_front', 'camera_fright', 'camera_rright', 'camera_bright', 'camera_bleft', 'camera_lleft', 'camera_fleft'])

# %%
data['lidar_points']
# Out:
# array([[2.8853467e+00, 4.9145428e+01, 1.2676771e+01, 1.1764706e-01],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#        [1.3225386e+00, 6.4207779e+01, 1.4921157e+01, 7.8431377e-03],
#        ...,
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#       dtype=float32)

# %%
points = data['lidar_points']
points
# Out:
# array([[2.8853467e+00, 4.9145428e+01, 1.2676771e+01, 1.1764706e-01],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#        [1.3225386e+00, 6.4207779e+01, 1.4921157e+01, 7.8431377e-03],
#        ...,
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#       dtype=float32)

# %%
points[:, 0:3].tolist().count([0, 0, 0])
# Out:
# 266162

# %%
data['pos']
# Out:
# array([[116.32094811,  39.98813634,  51.6027    ]])

# %%
data['ori']
# Out:
# array([[0.00670965, 0.00718223, 0.0411381 ]])

# %%
data['pos_ori_cov']
# Out:
# array([[3.43310000e+000, 3.20660000e+000, 9.35790000e+000,
#         4.63817943e-310, 3.16202013e-322, 1.72922976e-322]])

# %%
data['vel']
# Out:
# array([[0.0132, 0.0176, 0.024 ]])

# %%
data['omg']
# Out:
# array([[0., 0., 0.]])

# %%
data['camera_front'].shape
# Out:
# (1200, 1920, 3)

# %%
from PIL import Image

im = Image.fromarray(data['camera_bleft'])

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1200>

# %%
im.save(r"D:\Desktop\BasicProject\魏宏锐\中科院电子所\bleft.jpg")

# %%
os.path.basename(r"D:\Desktop\BasicProject\魏宏锐\中科院电子所\bleft.jpg")
# Out:
# 'bleft.jpg'

# %%
import re

# %%
a = "jhi07328BF"
if re.findall('BF', a):
    print(1)
# Out:
# 1

# %%
3/2
# Out:
# 1.5
